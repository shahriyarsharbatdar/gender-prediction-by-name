# %% [markdown]
# # Gender Prediction By Name

# %%
# !pip install names-dataset
# !pip install Faker

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
from names_dataset import NameDataset
from faker import Faker
fake = Faker(['en_US','fa'])
nd = NameDataset()

# %% [markdown]
# # Make a fake data frame

# %%
df = pd.DataFrame(
    {
    "people" : [fake.name() for _ in range(100)],
    }
)

# %%
df
# Out:
#                            people
# 0                     Maria Olsen
# 1                     Julia Allen
# 2                      سارا زارعی
# 3                     حلما مجتبوی
# 4                      سارا سعیدی
# ..                            ...
# 95                Barbara Aguilar
# 96               Nathaniel Jordan
# 97                   آرش خسروجردی
# 98                  Thomas Porter
# 99  سرکار خانم دکتر مائده حریریان
#
# [100 rows x 1 columns]

# %% [markdown]
# ## split full_name to first_name and last_name

# %%
def extract_name_parts(full_name):
    # Use regular expression to find titles and suffixes
    title_suffix_pattern = r'\b(?:Mr\.|Mrs\.|Ms\.|Dr\.|DVM|MD|جناب|آقای|دکتر|خانم|سرکار)\s?\b'

    # Remove titles and suffixes from the full name
    name_without_title_suffix = re.sub(title_suffix_pattern, '', full_name, flags=re.IGNORECASE)

    # Split the name into words
    words = name_without_title_suffix.split()

    # First name is the combination of all words except the last one
    first_name = ' '.join(words[:-1])

    # Last name is the last word
    last_name = words[-1]

    return first_name, last_name

# %% [markdown]
# ### Add first name and last name column to data frame

# %%
df['first name'] = df['people'].apply(lambda fn : extract_name_parts(fn)[0])
df['last name'] = df['people'].apply(lambda ln : extract_name_parts(ln)[1])
df
# Out:
#                            people first name last name
# 0                     Maria Olsen      Maria     Olsen
# 1                     Julia Allen      Julia     Allen
# 2                      سارا زارعی       سارا     زارعی
# 3                     حلما مجتبوی       حلما    مجتبوی
# 4                      سارا سعیدی       سارا     سعیدی
# ..                            ...        ...       ...
# 95                Barbara Aguilar    Barbara   Aguilar
# 96               Nathaniel Jordan  Nathaniel    Jordan
# 97                   آرش خسروجردی        آرش  خسروجردی
# 98                  Thomas Porter     Thomas    Porter
# 99  سرکار خانم دکتر مائده حریریان      مائده   حریریان
#
# [100 rows x 3 columns]

# %% [markdown]
# ## finding gender method

# %%
def name_to_gender(first_name):
    info = nd.search(first_name)['first_name']
    if info is None:
        return
    return max(info['gender'], key=info['gender'].get)

# %%
def name_to_gender_probability(first_name):
    info = nd.search(first_name)['first_name']
    if info is None:
        return
    return info['gender'][max(info['gender'], key=info['gender'].get)]

# %% [markdown]
# ### add gender column to data frame

# %%
df['gender'] = df['first name'].apply(lambda name : name_to_gender(name))

# %%
df['gender probablity'] = df['first name'].apply(lambda name : name_to_gender_probability(name))

# %%
df
# Out:
#                            people first name last name  gender  \
# 0                     Maria Olsen      Maria     Olsen  Female
# 1                     Julia Allen      Julia     Allen  Female
# 2                      سارا زارعی       سارا     زارعی  Female
# 3                     حلما مجتبوی       حلما    مجتبوی  Female
# 4                      سارا سعیدی       سارا     سعیدی  Female
# ..                            ...        ...       ...     ...
# 95                Barbara Aguilar    Barbara   Aguilar  Female
# 96               Nathaniel Jordan  Nathaniel    Jordan    Male
# 97                   آرش خسروجردی        آرش  خسروجردی    Male
# 98                  Thomas Porter     Thomas    Porter    Male
# 99  سرکار خانم دکتر مائده حریریان      مائده   حریریان  Female
#
#     gender probablity
# 0               0.987
# 1               0.989
# 2               0.937
# 3               0.781
# 4               0.937
# ..                ...
# 95              0.995
# 96              0.975
# 97              0.956
# 98              0.992
# 99              0.967
#
# [100 rows x 5 columns]

# %% [markdown]
# ## finding country method

# %%
def name_to_country(first_name):
    info = nd.search(first_name)['first_name']
    if info is None:
        return
    return max(info['country'], key=info['country'].get)

# %%
def name_to_country_probability(first_name):
    info = nd.search(first_name)['first_name']
    if info is None:
        return
    return info['country'][max(info['country'], key=info['country'].get)]

# %% [markdown]
# ### add country column to data frame

# %%
df['country'] = df['first name'].apply(lambda name : name_to_country(name))

# %%
df['country probablity'] = df['first name'].apply(lambda name : name_to_country_probability(name))

# %%
df
# Out:
#                            people first name last name  gender  \
# 0                     Maria Olsen      Maria     Olsen  Female
# 1                     Julia Allen      Julia     Allen  Female
# 2                      سارا زارعی       سارا     زارعی  Female
# 3                     حلما مجتبوی       حلما    مجتبوی  Female
# 4                      سارا سعیدی       سارا     سعیدی  Female
# ..                            ...        ...       ...     ...
# 95                Barbara Aguilar    Barbara   Aguilar  Female
# 96               Nathaniel Jordan  Nathaniel    Jordan    Male
# 97                   آرش خسروجردی        آرش  خسروجردی    Male
# 98                  Thomas Porter     Thomas    Porter    Male
# 99  سرکار خانم دکتر مائده حریریان      مائده   حریریان  Female
#
#     gender probablity                    country  country probablity
# 0               0.987                      Italy               0.290
# 1               0.989              United States               0.205
# 2               0.937               Saudi Arabia               0.507
# 3               0.781  Iran, Islamic Republic of               0.500
# 4               0.937               Saudi Arabia               0.507
# ..                ...                        ...                 ...
# 95              0.995                      Italy               0.489
# 96              0.975              United States               0.499
# 97              0.956  Iran, Islamic Republic of               0.585
# 98              0.992                     France               0.296
# 99              0.967                       Iraq               0.369
#
# [100 rows x 7 columns]

# %%
df['gender'] = df['gender'].replace({'Male': 0, 'Female': 1})

# %%
df
# Out:
#                            people first name last name  gender  \
# 0                     Maria Olsen      Maria     Olsen     1.0
# 1                     Julia Allen      Julia     Allen     1.0
# 2                      سارا زارعی       سارا     زارعی     1.0
# 3                     حلما مجتبوی       حلما    مجتبوی     1.0
# 4                      سارا سعیدی       سارا     سعیدی     1.0
# ..                            ...        ...       ...     ...
# 95                Barbara Aguilar    Barbara   Aguilar     1.0
# 96               Nathaniel Jordan  Nathaniel    Jordan     0.0
# 97                   آرش خسروجردی        آرش  خسروجردی     0.0
# 98                  Thomas Porter     Thomas    Porter     0.0
# 99  سرکار خانم دکتر مائده حریریان      مائده   حریریان     1.0
#
#     gender probablity                    country  country probablity
# 0               0.987                      Italy               0.290
# 1               0.989              United States               0.205
# 2               0.937               Saudi Arabia               0.507
# 3               0.781  Iran, Islamic Republic of               0.500
# 4               0.937               Saudi Arabia               0.507
# ..                ...                        ...                 ...
# 95              0.995                      Italy               0.489
# 96              0.975              United States               0.499
# 97              0.956  Iran, Islamic Republic of               0.585
# 98              0.992                     France               0.296
# 99              0.967                       Iraq               0.369
#
# [100 rows x 7 columns]

# %%
country_counts = df['country'].value_counts()

plt.figure(figsize=(8, 8))
pie_chart = country_counts.plot.pie(autopct='%1.1f%%', startangle=0, labeldistance=1.1)
pie_chart.set_ylabel('')  # To remove the default 'Country' label on the y-axis
plt.title('Country Distribution')
# Out:
# Text(0.5, 1.0, 'Country Distribution')
